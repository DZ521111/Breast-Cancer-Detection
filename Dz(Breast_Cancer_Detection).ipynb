# %%
"""
Created on Thu Aug 8 17:51:10 2019

@author: DHRUV _ the_dz

"""
# Out:
# '\nCreated on Thu Jun  4 17:51:10 2020\n\n@author: DHRUV _ the_dz\n\n'

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras_preprocessing
import sys
from google.colab import files

# %%
upload = files.upload()
df = pd.read_csv("Data.csv")
df.head(10)
# Out:
#      <input type="file" id="files-3605778a-9cf3-4563-a8bb-e6c423cef9f5" name="files[]" multiple disabled />
#      <output id="result-3605778a-9cf3-4563-a8bb-e6c423cef9f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data.csv to Data.csv
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
# 5    843786         M  ...                  0.12440          NaN
# 6    844359         M  ...                  0.08368          NaN
# ...

# %%
df.shape  #very simple DataSet
# Out:
# (569, 33)

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
#drop column with num or empty value
df.dropna(axis = 1, inplace = True)

# %%
df.shape
# Out:
# (569, 32)

# %%
#count the malignant or benign cells
df["diagnosis"].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# visualize the count
sns.countplot(df["diagnosis"], label = "count")

# %%
#encode categorical data value for machine learning purpose
from sklearn.preprocessing import LabelEncoder
labelencode_y = LabelEncoder()
df.iloc[:,1] = labelencode_y.fit_transform(df.iloc[:,1].values)
# M = 1 and B = 0

# %%
#pairplot
sns.pairplot(df.iloc[:,1:9], hue = 'diagnosis')

# %%
#5 row of data
df.head()
# Out:
#          id  diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302          1  ...          0.4601                  0.11890
# 1    842517          1  ...          0.2750                  0.08902
# 2  84300903          1  ...          0.3613                  0.08758
# 3  84348301          1  ...          0.6638                  0.17300
# 4  84358402          1  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
#correlation between column
df.iloc[:, 1:12].corr()
# Out:
#                         diagnosis  ...  fractal_dimension_mean
# diagnosis                1.000000  ...               -0.012838
# radius_mean              0.730029  ...               -0.311631
# texture_mean             0.415185  ...               -0.076437
# perimeter_mean           0.742636  ...               -0.261477
# area_mean                0.708984  ...               -0.283110
# smoothness_mean          0.358560  ...                0.584792
# compactness_mean         0.596534  ...                0.565369
# concavity_mean           0.696360  ...                0.336783
# concave points_mean      0.776614  ...                0.166917
# symmetry_mean            0.330499  ...                0.479921
# fractal_dimension_mean  -0.012838  ...                1.000000
#
# [11 rows x 11 columns]

# %%
#visualize the correlations
plt.figure(figsize = (10,10))
sns.heatmap(df.iloc[:, 1:12].corr(), annot = True, fmt = '.0%')

# %%
# spliting train and test
X = df.iloc[:, 2:].values
Y = df.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.30, random_state = 40)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
X_train
# Out:
# array([[-0.67237593, -0.6548285 , -0.54716701, ...,  1.08508176,
#          4.71125141,  1.15290927],
#        [-1.10685194, -1.10933913, -1.07117065, ..., -1.16430929,
#         -0.78567722,  0.06472014],
#        [ 0.31506953,  1.45730914,  0.41193582, ...,  1.33045304,
#          1.83606149,  0.89827781],
#        ...,
#        [-0.13351283,  0.37815021, -0.08789564, ...,  0.60822814,
#          0.46841249,  1.87956978],
#        [ 1.50846792,  3.20729659,  1.46076249, ...,  0.71471002,
#         -0.32650264, -0.48778207],
#        [-0.02066192, -1.55412761, -0.09486051, ..., -0.88406133,
#         -1.33537008, -0.77904682]])

# %%
#create model
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

def models(X_train, Y_train):
  #Logistic Regression
  lr = LogisticRegression(random_state = 40)
  lr.fit(X_train, Y_train)

  # tree
  tree = DecisionTreeClassifier(criterion = "entropy", random_state = 40)
  tree.fit(X_train, Y_train)

  #random forest
  rf = RandomForestClassifier(n_estimators = 30, criterion = "entropy", random_state = 40)
  rf.fit(X_train, Y_train)

  print("Logistic accuracy", lr.score(X_train, Y_train))
  print("DecisionTree accuracy", tree.score(X_train, Y_train))
  print("RandomForest accuracy", rf.score(X_train, Y_train))

  return lr, tree, rf

# %%
model = models(X_train, Y_train)
# Out:
# Logistic accuracy 0.9874371859296482
# DecisionTree accuracy 1.0
# RandomForest accuracy 0.9974874371859297

# %%
from sklearn.metrics import confusion_matrix
cm0 = confusion_matrix(Y_test, model[0].predict(X_test))
test_accuracy = (cm0[0][0] + cm0[1][1])/sum((cm0.sum(axis=1)))
print(test_accuracy)
cm0
# Out:
# 0.9649122807017544
# array([[111,   4],
#        [  2,  54]])

# %%
from sklearn.metrics import confusion_matrix
cm1 = confusion_matrix(Y_test, model[1].predict(X_test))
test_accuracy = (cm1[0][0] + cm1[1][1])/sum((cm1.sum(axis=1)))
print(test_accuracy)
cm1
# Out:
# 0.9415204678362573
# array([[107,   8],
#        [  2,  54]])

# %%
from sklearn.metrics import confusion_matrix
cm2 = confusion_matrix(Y_test, model[2].predict(X_test))
test_accuracy = (cm2[0][0] + cm2[1][1])/sum((cm2.sum(axis=1)))
print(test_accuracy)
cm2
# Out:
# 0.9707602339181286
# array([[111,   4],
#        [  1,  55]])
